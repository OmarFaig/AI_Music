# %%
import pandas as pd
import librosa
import io
import numpy as np

# %%
data_path = "0000.parquet"
df = pd.read_parquet(data_path)
display(df)
# Out:
#                                                  audio  song_id  genre_id  \
# 0    {'bytes': b'OggS\x00\x02\x00\x00\x00\x00\x00\x...       66        13
# 1    {'bytes': b'OggS\x00\x02\x00\x00\x00\x00\x00\x...      150        13
# 2    {'bytes': b'OggS\x00\x02\x00\x00\x00\x00\x00\x...      202        13
# 3    {'bytes': b'OggS\x00\x02\x00\x00\x00\x00\x00\x...      402        13
# 4    {'bytes': b'OggS\x00\x02\x00\x00\x00\x00\x00\x...      512        13
# ..                                                 ...      ...       ...
# 301  {'bytes': b'OggS\x00\x02\x00\x00\x00\x00\x00\x...    24619        13
# 302  {'bytes': b'OggS\x00\x02\x00\x00\x00\x00\x00\x...    24780        13
# 303  {'bytes': b'OggS\x00\x02\x00\x00\x00\x00\x00\x...    24915        13
# 304  {'bytes': b'OggS\x00\x02\x00\x00\x00\x00\x00\x...    24967        13
# 305  {'bytes': b'OggS\x00\x02\x00\x00\x00\x00\x00\x...    24983        13
#
#     genre
# 0    Jazz
# 1    Jazz
# 2    Jazz
# 3    Jazz
# 4    Jazz
# ..    ...
# 301  Jazz
# 302  Jazz
# 303  Jazz
# 304  Jazz
# 305  Jazz
#
# [306 rows x 4 columns]

# %%
# Function to convert audio bytes to waveform
def bytes_to_waveform(audio_bytes):
    # Decode the byte array to an audio format
    audio_buffer = io.BytesIO(audio_bytes)
    # Load the audio file using librosa
    waveform, sr = librosa.load(audio_buffer, sr=None)
    return waveform, sr

# Extract waveforms and sample rates
waveforms = []
for index, row in df.iterrows():
    audio_bytes = row['audio']['bytes']
    waveform, sr = bytes_to_waveform(audio_bytes)
    waveforms.append(waveform)

# Convert list of waveforms to numpy array for further processing
waveforms = np.array(waveforms)

print(f"Loaded {len(waveforms)} audio samples.")
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/omar/TUM/05_projects/AI_Music/venv/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/omar/TUM/05_projects/AI_Music/venv/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/omar/TUM/05_projects/AI_Music/venv/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/omar/TUM/05_projects/AI_Music/venv/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/omar/TUM/05_projects/AI_Music/venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/omar/TUM/05_projects/AI_Music/venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/omar/TUM/05_projects/AI_Music/venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/omar/TUM/05_projects/AI_Music/venv/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/omar/TUM/05_projects/AI_Music/venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/omar/TUM/05_projects/AI_Music/venv/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/home/omar/TUM/05_projects/AI_Music/venv/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/omar/TUM/05_projects/AI_Music/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/omar/TUM/05_projects/AI_Music/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/omar/TUM/05_projects/AI_Music/venv/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/omar/TUM/05_projects/AI_Music/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/omar/TUM/05_projects/AI_Music/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/omar/TUM/05_projects/AI_Music/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_554566/2213685176.py", line 13, in <module>
#     waveform, sr = bytes_to_waveform(audio_bytes)
#   File "/tmp/ipykernel_554566/2213685176.py", line 6, in bytes_to_waveform
#     waveform, sr = librosa.load(audio_buffer, sr=None)
#   File "/home/omar/TUM/05_projects/AI_Music/venv/lib/python3.10/site-packages/lazy_loader/__init__.py", line 83, in __getattr__
#     attr = getattr(submod, name)
#   File "/home/omar/TUM/05_projects/AI_Music/venv/lib/python3.10/site-packages/lazy_loader/__init__.py", line 82, in __getattr__
#     submod = importlib.import_module(submod_path)
#   File "/usr/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/home/omar/TUM/05_projects/AI_Music/venv/lib/python3.10/site-packages/librosa/core/audio.py", line 15, in <module>
#     import soxr
#   File "/home/omar/TUM/05_projects/AI_Music/venv/lib/python3.10/site-packages/soxr/__init__.py", line 10, in <module>
#     from . import cysoxr
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 13
#      11 for index, row in df.iterrows():
#      12     audio_bytes = row['audio']['bytes']
# ---> 13     waveform, sr = bytes_to_waveform(audio_bytes)
#      14     waveforms.append(waveform)
#      16 # Convert list of waveforms to numpy array for further processing
#
# Cell In[17], line 6, in bytes_to_waveform(audio_bytes)
#       4 audio_buffer = io.BytesIO(audio_bytes)
#       5 # Load the audio file using librosa
# ----> 6 waveform, sr = librosa.load(audio_buffer, sr=None)
#       7 return waveform, sr
#
# File ~/TUM/05_projects/AI_Music/venv/lib/python3.10/site-packages/lazy_loader/__init__.py:83, in attach.<locals>.__getattr__(name)
#      81 submod_path = f"{package_name}.{attr_to_modules[name]}"
#      82 submod = importlib.import_module(submod_path)
# ---> 83 attr = getattr(submod, name)
#      85 # If the attribute lives in a file (module) with the same
#      86 # name as the attribute, ensure that the attribute and *not*
#      87 # the module is accessible on the package.
#      88 if name == attr_to_modules[name]:
#
# File ~/TUM/05_projects/AI_Music/venv/lib/python3.10/site-packages/lazy_loader/__init__.py:82, in attach.<locals>.__getattr__(name)
#      80 elif name in attr_to_modules:
#      81     submod_path = f"{package_name}.{attr_to_modules[name]}"
# ---> 82     submod = importlib.import_module(submod_path)
#      83     attr = getattr(submod, name)
#      85     # If the attribute lives in a file (module) with the same
#      86     # name as the attribute, ensure that the attribute and *not*
#      87     # the module is accessible on the package.
#
# File /usr/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/TUM/05_projects/AI_Music/venv/lib/python3.10/site-packages/librosa/core/audio.py:15
#      13 import scipy
#      14 import scipy.signal
# ---> 15 import soxr
#      16 import lazy_loader as lazy
#      18 from numba import jit, stencil, guvectorize
#
# File ~/TUM/05_projects/AI_Music/venv/lib/python3.10/site-packages/soxr/__init__.py:10
#       6 import warnings
#       8 import numpy as np
# ---> 10 from . import cysoxr
#      11 from .cysoxr import QQ, LQ, MQ, HQ, VHQ
#      12 from ._version import version as __version__
#
# File src/soxr/cysoxr.pyx:1, in init soxr.cysoxr()
#
# ImportError: numpy.core.multiarray failed to import (auto-generated because you didn't call 'numpy.import_array()' after cimporting numpy; use '<void>numpy._import_array' to disable if you are certain you don't need it).
